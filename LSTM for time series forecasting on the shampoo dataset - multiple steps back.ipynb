# %% [markdown]
# ## LSTM for time series forecasting on the shampoo dataset - multiple steps back
# From: Vicente Guerrero
#
# https://viclule.github.io/
#
# Date: 14.03.2019
#
#
# Based on the article from Jason Brownlee.
# https://machinelearningmastery.com/time-series-forecasting-long-short-term-memory-network-python/
#
# ##### Shampoo Sales Dataset
# This dataset describes the monthly number of sales of shampoo over a 3-year period.
#
# The units are a sales count and there are 36 observations. The original dataset is credited to Makridakis, Wheelwright, and Hyndman (1998).

# %%
# forces tensorflow to run on the CPU
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from math import sqrt

# %%
# load dataset
def parser(x):
    return pd.datetime.strptime('201'+x, '%Y-%m')

df = pd.read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
df.head()
# Out:
# Month
# 2011-01-01    266.0
# 2011-02-01    145.9
# 2011-03-01    183.1
# 2011-04-01    119.3
# 2011-05-01    180.3
# Name: Sales, dtype: float64

# %%
df.plot()
plt.title('original dataset')
plt.show()

# %% [markdown]
# #### 1. Baseline model
# Persistence Model Forecast.
#
# The persistence forecast is where the observation from the prior time step (t-1) is used to predict the observation at the current time step (t).

# %%
# split data into train and test
values = df.values
train, test = values[0:-12], values[-12:]

# %%
# walk-forward validation
history = train
predictions = np.zeros(len(test))
for i, x in enumerate(test):
    # make prediction
    predictions[i] = history[-1]
    # observation
    history = np.append(history, x)
# report performance
rmse = math.sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)
# line plot of observed vs predicted
plt.plot(test, label='test')
plt.plot(predictions, label='prediction')
plt.legend()
plt.show()
# Out:
# RMSE: 136.761

# %% [markdown]
# #### 2. Transform the time series into a supervised learning problem

# %%
lag_steps = 2
n_features = 1

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = np.zeros(len(dataset) - 1)
    for i in range(interval, len(dataset)):
        diff[i - 1] = dataset[i] - dataset[i - interval]
    return diff


# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# %%
# transform data to be stationary
diff_values = difference(values, 1)

# %%
# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    assert lag >= 1
    df = pd.Series(data)
    columns = [df.shift(i) for i in range(1, lag + 1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df

# %%
supervised = timeseries_to_supervised(diff_values, lag_steps)
supervised.head()
# Out:
#        0      1      2
# 0    0.0    0.0 -120.1
# 1 -120.1    0.0   37.2
# 2   37.2 -120.1  -63.8
# 3  -63.8   37.2   61.0
# 4   61.0  -63.8  -11.8

# %%
# split data into train and test-sets
train, test = supervised.values[0:-12], supervised.values[-12:]

# %%
# scale train and test data to [-1, 1]
def scale(train, test):
    # fit scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train)
    # transform train
    train_scaled = scaler.transform(train)
    # transform test
    test_scaled = scaler.transform(test)
    return scaler, train_scaled, test_scaled


# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
    new_row = [x for x in X] + [value]
    array = np.array(new_row)
    array = array.reshape(1, -1)
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]

# %%
# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)

# %%
train_scaled.shape
# Out:
# (23, 3)

# %% [markdown]
# #### 3. Fit and evaluate a LSTM model

# %%
# fit an LSTM network to training data
def fit_lstm(train, batch_size, lag_steps, n_features, nb_epoch, neurons):
    X, y = train[:, 0:-1], train[:, -1]
    # reshape input to be 3D [samples, timesteps, features]
    X = X.reshape(-1, lag_steps, n_features)
    # build the model
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        # do not shuffle the training data points
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
        # reset lstm states between batches
        model.reset_states()
        if i%100 == 0:
            print('epoch:', i)
    return model
 
# make a one-step forecast
def forecast_lstm(model, batch_size, lag_steps, n_features, X):
    X = X.reshape(-1, lag_steps, n_features)
    yhat = model.predict(X, batch_size=batch_size)
    return yhat[0,0]

# %%
# fit the model
lstm_model = fit_lstm(train_scaled, 1, lag_steps, n_features, 1500, 1)
# Out:
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400

# %%
# forecast the entire training dataset to build up state for forecasting
train_reshaped = train_scaled[:, 0:-1].reshape(-1, lag_steps, n_features)
lstm_model.predict(train_reshaped, batch_size=1)
# Out:
# array([[-0.00100088],
#        [ 0.02134714],
#        [-0.41234764],
#        [-0.05735108],
#        [-0.39336082],
#        [ 0.00574663],
#        [-0.26740578],
#        [ 0.04495338],
#        [-0.06464452],
#        [-0.09641972],
#        [-0.5312389 ],
#        [ 0.2186966 ],
#        [-0.34428534],
#        [-0.14244601],
#        [-0.3711364 ],
#        [-0.08359215],
#        [ 0.14079346],
#        [-0.509408  ],
#        [ 0.20608482],
#        [-0.38415983],
#        [ 0.10191144],
#        [-0.52162087],
#        [ 0.28902   ]], dtype=float32)

# %%
# walk-forward validation on the test data
predictions = []
for i in range(len(test_scaled)):
    # make one-step forecast
    X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, lag_steps, n_features, X)
    # invert scaling
    yhat = invert_scale(scaler, X, yhat)
    # invert differencing
    yhat = inverse_difference(values, yhat, len(test_scaled)+1-i)
    # store forecast
    predictions.append(yhat)
    expected = values[len(train) + i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 
# report performance
rmse = sqrt(mean_squared_error(values[-12:], predictions))
print('Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
plt.plot(values[-12:], label='test')
plt.plot(predictions, label='prediction')
plt.legend()
plt.show()
# Out:
# Month=1, Predicted=276.547705, Expected=339.700000
# Month=2, Predicted=381.095705, Expected=440.400000
# Month=3, Predicted=396.954639, Expected=315.900000
# Month=4, Predicted=389.122002, Expected=439.300000
# Month=5, Predicted=368.707521, Expected=401.300000
# Month=6, Predicted=491.331319, Expected=437.400000
# Month=7, Predicted=440.982257, Expected=575.500000
# Month=8, Predicted=547.669101, Expected=407.600000
# Month=9, Predicted=483.343561, Expected=682.000000
# Month=10, Predicted=611.361718, Expected=475.300000
# Month=11, Predicted=532.616869, Expected=581.300000
# Month=12, Predicted=510.653697, Expected=646.900000
# Test RMSE: 106.922

# %% [markdown]
# It shows a slightly better performance than the persistance model (RMSE: 136.761).

# %% [markdown]
# #### 4. Build a Robust Result
# A difficulty with neural networks is that they give different results with different starting conditions.
#
#
# One approach might be to fix the random number seed used by Keras to ensure the results are reproducible. Another approach would be to control for the random initial conditions using a different experimental setup.
#
#
# We can repeat the experiment from the previous section multiple times, then take the average RMSE as an indication of how well the configuration would be expected to perform on unseen data on average.
#
# This is often called multiple repeats or multiple restarts.
#
#
# We can wrap the model fitting and walk-forward validation in a loop of fixed number of repeats. Each iteration the RMSE of the run can be recorded. We can then summarize the distribution of RMSE scores.

# %%
# repeat experiment
repeats = 20
error_scores = []
for r in range(repeats):
    # fit the model
    lstm_model = fit_lstm(train_scaled, 1, lag_steps, n_features, 1500, 1)
    # forecast the entire training dataset to build up state for forecasting
    train_reshaped = train_scaled[i, 0:-1].reshape(-1, lag_steps, n_features)
    lstm_model.predict(train_reshaped, batch_size=1)
    # walk-forward validation on the test data
    predictions = []
    for i in range(len(test_scaled)):
    # make one-step forecast
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        yhat = forecast_lstm(lstm_model, 1, lag_steps, n_features, X)
        # invert scaling
        yhat = invert_scale(scaler, X, yhat)
        # invert differencing
        yhat = inverse_difference(values, yhat, len(test_scaled)+1-i)
        # store forecast
        predictions.append(yhat)
    # report performance
    rmse = sqrt(mean_squared_error(values[-12:], predictions))
    print('%d) Test RMSE: %.3f' % (r+1, rmse))
    error_scores.append(rmse)
# Out:
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 1) Test RMSE: 118.949
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 2) Test RMSE: 101.074
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 3) Test RMSE: 105.627
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 4) Test RMSE: 124.122
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 5) Test RMSE: 103.163
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 6) Test RMSE: 107.965
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 7) Test RMSE: 99.583
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 8) Test RMSE: 124.690
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 9) Test RMSE: 107.055
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 10) Test RMSE: 121.530
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 11) Test RMSE: 102.357
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 12) Test RMSE: 107.369
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 13) Test RMSE: 140.144
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 14) Test RMSE: 136.408
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 15) Test RMSE: 105.675
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 16) Test RMSE: 115.640
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 17) Test RMSE: 372.122
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 18) Test RMSE: 118.796
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 19) Test RMSE: 108.905
# epoch: 0
# epoch: 100
# epoch: 200
# epoch: 300
# epoch: 400
# epoch: 500
# epoch: 600
# epoch: 700
# epoch: 800
# epoch: 900
# epoch: 1000
# epoch: 1100
# epoch: 1200
# epoch: 1300
# epoch: 1400
# 20) Test RMSE: 131.230

# %%
# summarize results
results = pd.DataFrame()
results['rmse'] = error_scores
print(results.describe())
results.boxplot()
plt.title('A box and whisker plot')
plt.show()
# Out:
#              rmse
# count   20.000000
# mean   127.620265
# std     58.779069
# min     99.582512
# 25%    105.663376
# 50%    112.272827
# 75%    124.264290
# max    372.121552

# %% [markdown]
# mean   127.620265 ... It is slightly better then the baseline model (RMSE: 136.761).
